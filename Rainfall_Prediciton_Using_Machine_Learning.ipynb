# %% [markdown]
# <a href="https://colab.research.google.com/github/patibandlavenkatamanideep/Rainfall-Prediction-Using-Machine-Learning/blob/main/Rainfall_Prediciton_Using_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1dca862-b4a9-48f1-a3b3-28b186e2ea1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1dca862-b4a9-48f1-a3b3-28b186e2ea1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Importing the Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import pickle

# %% [markdown]
# # Data Collection and Processing

# %%
#loading the data
data = pd.read_csv("Rainfall.csv")

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape
# Out:
# (366, 12)

# %%
data.head()
# Out:
#    day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0    1     1025.9     19.9         18.3     16.8      13.1         72      49
# 1    2     1022.0     21.7         18.9     17.2      15.6         81      83
# 2    3     1019.7     20.3         19.3     18.0      18.4         95      91
# 3    4     1018.9     22.3         20.6     19.1      18.8         90      88
# 4    5     1015.9     21.3         20.7     20.2      19.9         95      81
#
#   rainfall  sunshine           winddirection  windspeed
# 0      yes       9.3                    80.0       26.3
# 1      yes       0.6                    50.0       15.3
# 2      yes       0.0                    40.0       14.2
# 3      yes       1.0                    50.0       16.9
# 4      yes       0.0                    40.0       13.7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
data.isna().sum()
# Out:
# day                       0
# pressure                  0
# maxtemp                   0
# temparature               0
# mintemp                   0
# dewpoint                  0
# humidity                  0
# cloud                     0
# rainfall                  0
# sunshine                  0
#          winddirection    1
# windspeed                 1
# dtype: int64

# %%
#checking for spaces in column names

data.columns
# Out:
# Index(['day', 'pressure ', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity ', 'cloud ', 'rainfall', 'sunshine', '         winddirection',
#        'windspeed'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()
data.columns
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
print(" Data Info: ")
data.info()
# Out:
#  Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            366 non-null    int64
#  1   pressure       366 non-null    float64
#  2   maxtemp        366 non-null    float64
#  3   temparature    366 non-null    float64
#  4   mintemp        366 non-null    float64
#  5   dewpoint       366 non-null    float64
#  6   humidity       366 non-null    int64
#  7   cloud          366 non-null    int64
#  8   rainfall       366 non-null    object
#  9   sunshine       366 non-null    float64
#  10  winddirection  365 non-null    float64
#  11  windspeed      365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
data = data.drop(columns="day")

# %%
data.head()
# Out:
#    pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0    1025.9     19.9         18.3     16.8      13.1        72     49
# 1    1022.0     21.7         18.9     17.2      15.6        81     83
# 2    1019.7     20.3         19.3     18.0      18.4        95     91
# 3    1018.9     22.3         20.6     19.1      18.8        90     88
# 4    1015.9     21.3         20.7     20.2      19.9        95     81
#
#   rainfall  sunshine  winddirection  windspeed
# 0      yes       9.3           80.0       26.3
# 1      yes       0.6           50.0       15.3
# 2      yes       0.0           40.0       14.2
# 3      yes       1.0           50.0       16.9
# 4      yes       0.0           40.0       13.7

# %%
#checking for nulls
data.isnull().sum()
# Out:
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    1
# windspeed        1
# dtype: int64

# %%
#handling missing values
data.winddirection.unique()
# Out:
# array([ 80.,  50.,  40.,  20.,  30.,  60.,  70.,  10., 200., 220., 120.,
#        190., 210., 300., 240., 180., 230.,  90., 170., 150., 100., 130.,
#         nan, 160., 270., 280., 250., 260., 290., 350., 110., 140.])

# %%
data["winddirection"] = data["winddirection"].fillna(data["winddirection"].mode()[0])

# %%
data.windspeed.unique()
# Out:
# array([26.3, 15.3, 14.2, 16.9, 13.7, 14.5, 21.5, 14.3, 39.3, 37.7, 23.3,
#        23.9, 24.4, 33.2, 37.5, 40. , 23.4, 28.4, 38. , 50.6, 26.2, 35.3,
#        55.5, 59.5, 28.7, 21.3, 29.6, 28.8, 25. , 21.2, 43.1, 31.9, 27.3,
#         9.1, 44.7, 20.5, 16.7, 17.2, 22. , 15.8, 13.9, 10.2, 33.5, 23.5,
#        19.2, 18.6, 22.2, 19.3, 28. , 20.4, 15.2,  9.2, 34.2, 27.1, 14.7,
#        15.4, 13.3,  6.6, 13.8, 15.1, 39.7, 36. , 22.8, 26.7, 26.5, 13.1,
#        12.5, 38.3, 42. , 19.4, 13.4, 14.6, 26.9, 14.8,  4.5,  8.3,  8. ,
#        20. , 10. , 17.3, 31.8, 29.8, 11.2, 16. , 19.6, 20.9,  7.3, 11.1,
#        13. ,  8.5, 24.2, 20.2, 30.5, 27. , 23.7, 11.8, 15.5, 12.1,  9.5,
#        16.3, 12. , 26. , 28.6, 24.9, 28.3, 15.7, 21.9, 39.5, 30.3, 26.4,
#        22.3, 25.9, 11.3,  7.9,  7.4, 16.2, 34.8, 32.5, 24. , 19. , 25.2,
#        31.7, 27.4, 20.8,  9.8, 12.6,  nan, 24.3, 30. , 29.3, 23.2, 12.8,
#        19.8, 12.4, 10.9,  9.6,  9. , 11.9, 26.1, 25.1, 33. , 22.5, 24.8,
# ...

# %%
data["windspeed"] = data['windspeed'].fillna(data['windspeed'].mode()[0])

# %%
data.isna().sum()
# Out:
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
#converting categorical data columns to numerical
data["rainfall"] = data["rainfall"].map({"yes" : 1, "no" : 0 })

# %%
data.head()
# Out:
#    pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0    1025.9     19.9         18.3     16.8      13.1        72     49
# 1    1022.0     21.7         18.9     17.2      15.6        81     83
# 2    1019.7     20.3         19.3     18.0      18.4        95     91
# 3    1018.9     22.3         20.6     19.1      18.8        90     88
# 4    1015.9     21.3         20.7     20.2      19.9        95     81
#
#    rainfall  sunshine  winddirection  windspeed
# 0         1       9.3           80.0       26.3
# 1         1       0.6           50.0       15.3
# 2         1       0.0           40.0       14.2
# 3         1       1.0           50.0       16.9
# 4         1       0.0           40.0       13.7

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.shape
# Out:
# (366, 11)

# %%
sns.set(style= "whitegrid")

# %%
data.describe()
# Out:
#           pressure     maxtemp  temparature     mintemp    dewpoint  \
# count   366.000000  366.000000   366.000000  366.000000  366.000000
# mean   1013.742623   26.191257    23.747268   21.894536   19.989071
# std       6.414776    5.978343     5.632813    5.594153    5.997021
# min     998.500000    7.100000     4.900000    3.100000   -0.400000
# 25%    1008.500000   21.200000    18.825000   17.125000   16.125000
# 50%    1013.000000   27.750000    25.450000   23.700000   21.950000
# 75%    1018.100000   31.200000    28.600000   26.575000   25.000000
# max    1034.600000   36.300000    32.400000   30.000000   26.700000
#
#          humidity       cloud    rainfall    sunshine  winddirection  \
# count  366.000000  366.000000  366.000000  366.000000     366.000000
# mean    80.177596   71.128415    0.680328    4.419399     101.284153
# std     10.062470   21.798012    0.466988    3.934398      81.722827
# min     36.000000    0.000000    0.000000    0.000000      10.000000
# ...

# %%
data.columns
# Out:
# Index(['pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint', 'humidity',
#        'cloud', 'rainfall', 'sunshine', 'winddirection', 'windspeed'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))
for i, column in enumerate(data.columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(data[column], kde=True)
    plt.title(f"Distribution of {column}")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="rainfall", data=data)
plt.title("Rainfall Distribution")
# Out:
# Text(0.5, 1.0, 'Rainfall Distribution')

# %%
#correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.figure(figsize=(10, 8))

for i, column in enumerate(data.columns, 1):
    plt.subplot(4,3,i)
    sns.boxplot(data[column])
    plt.title(f"Boxplot of {column}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Processing

# %%
# drop highly co-related columns
data = data.drop(columns=["maxtemp", "temparature", "mintemp"])

# %%
data.head()
# Out:
#    pressure  dewpoint  humidity  cloud  rainfall  sunshine  winddirection  \
# 0    1025.9      13.1        72     49         1       9.3           80.0
# 1    1022.0      15.6        81     83         1       0.6           50.0
# 2    1019.7      18.4        95     91         1       0.0           40.0
# 3    1018.9      18.8        90     88         1       1.0           50.0
# 4    1015.9      19.9        95     81         1       0.0           40.0
#
#    windspeed
# 0       26.3
# 1       15.3
# 2       14.2
# 3       16.9
# 4       13.7

# %%
data["rainfall"].value_counts()
# Out:
# rainfall
# 1    249
# 0    117
# Name: count, dtype: int64

# %%
# seperate majority and monority class
df_majority = data[data["rainfall"] == 1]
df_minority = data[data["rainfall"] == 0]

# %%
print(df_majority.shape)
print(df_minority.shape)
# Out:
# (249, 8)
# (117, 8)

# %%
#undersampling majority class to match minority class
df_majority_undersampled = resample(df_majority, replace=False, n_samples=len(df_minority), random_state=42)

# %%
df_majority_undersampled.shape
# Out:
# (117, 8)

# %%
df_undersampled = pd.concat([df_majority_undersampled, df_minority])

# %%
df_undersampled.shape
# Out:
# (234, 8)

# %%
#shuffle the final dataframe
df_undersampled = df_undersampled.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df_undersampled.head()
# Out:
#    pressure  dewpoint  humidity  cloud  rainfall  sunshine  winddirection  \
# 0    1022.2      14.1        78     90         1       0.0           30.0
# 1    1013.4      19.5        69     17         0      10.5           70.0
# 2    1006.1      24.4        74     27         0      10.8          220.0
# 3    1007.6      24.8        85     84         1       1.8           70.0
# 4    1021.2       8.4        66     18         0      10.1           20.0
#
#    windspeed
# 0       28.5
# 1       12.4
# 2        8.7
# 3       34.8
# 4       24.4

# %%
df_undersampled['rainfall'].value_counts()
# Out:
# rainfall
# 1    117
# 0    117
# Name: count, dtype: int64

# %%
#splitting features and target as X and Y
X = df_undersampled.drop(columns="rainfall")
Y = df_undersampled["rainfall"]

# %%
#splitting the data into train & test
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [50,100, 200],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'min_samples_leaf' : [1,2,3,4,5],

}

# %%
#Hyperparameter tuning using Gridsearch cv
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'n_estimators': [50, 100, 200]},
#              verbose=2)

# %%
best_rf_model = grid_search.best_estimator_
print("best parameters for", grid_search.best_estimator_)
# Out:
# best parameters for RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)

# %% [markdown]
# # Model Evaluation

# %%
cv_scores = cross_val_score(best_rf_model, x_train, y_train, cv=5)
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.71052632 0.78947368 0.86486486 0.78378378 0.91891892]
# Mean CV Score: 0.8135135135135135

# %%
#testing performance
y_pred = best_rf_model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7446808510638298
# Confusion Matrix:
#  [[16  8]
#  [ 4 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        24
#            1       0.70      0.83      0.76        23
#
#     accuracy                           0.74        47
#    macro avg       0.75      0.75      0.74        47
# weighted avg       0.75      0.74      0.74        47

# %% [markdown]
# # Prediction on unseen data

# %%
input_data = (1015,91.4,95, 81, 0, 40, 13.7)

input_df = pd.DataFrame([input_data], columns=X.columns)

prediction = best_rf_model.predict(input_df)

# %%
input_df
# Out:
#    pressure  dewpoint  humidity  cloud  sunshine  winddirection  windspeed
# 0      1015      91.4        95     81         0             40       13.7

# %%
print(prediction)
# Out:
# [1]

# %%
print("prediction result : ", "Rainfall " if prediction[0] == 1 else "No rainfall ..! ")
# Out:
# prediction result :  Rainfall

# %%
#saving the model and featurs into pickle file
model_data = {'model' : best_rf_model, 'features' : list(X.columns)}

# %% [markdown]
# # Load the saved model, file and use it for Prediction

# %%
import pickle
import pandas as pd

# %%
#load the train model and featurs from the pickle file
with open('model.pkl', 'rb') as file:
    model_data = pickle.load(file)

# %%
model = model_data['data']
features = model_data['features']
